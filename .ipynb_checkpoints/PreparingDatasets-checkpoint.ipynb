# %%
from sqlalchemy import create_engine, MetaData, Table, select, func
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date
from sqlalchemy import ForeignKey
from datetime import datetime, timedelta
from sqlalchemy import Column, Integer, String, Float, ForeignKey, Sequence, CheckConstraint, UniqueConstraint
import pandas as pd
from sqlalchemy.orm import sessionmaker
from sqlalchemy import or_, and_
from sqlalchemy import distinct

# %%
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"
engine = create_engine(db_string)
Base = declarative_base()

# %% [markdown]
# ### Preparation of datasets

# %% [markdown]
# * Covid

# %%
data_covid = pd.read_excel('covid.xlsx')
new1 = data_covid[['Country', 'diabetes_prevalence', 'hospital_beds_per_thousand']]
new_enter = data_covid['stringency_index']
country_data = data_covid[['Country', 'Continent']]
del data_covid['diabetes_prevalence'], data_covid['hospital_beds_per_thousand'], data_covid['stringency_index'],data_covid['Continent']
data_covid = data_covid.rename(columns={'Country': "country", \
                                        'Date' : 'date'})
data_covid.head()
# Out:
#        country       date  totalCases  newCases  totalDeaths  newDeaths
# 0  Afghanistan 2020-01-01           0         0            0          0
# 1  Afghanistan 2020-01-02           0         0            0          0
# 2  Afghanistan 2020-01-03           0         0            0          0
# 3  Afghanistan 2020-01-04           0         0            0          0
# 4  Afghanistan 2020-01-05           0         0            0          0

# %% [markdown]
# * Education

# %%
data_edu = pd.read_excel('edukacja2.xlsx').drop_duplicates().dropna()
data_edu = data_edu.pivot(index='countryName', columns='Series Name', values='2016 [YR2016]')
data_edu = data_edu.rename(columns={'Children out of school (% of primary school age)': "childrenOutOfSchool", \
                            'Compulsory education, duration (years)' : 'compulsoryEducation',\
                            'Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)' : 'educationalAttainmentAtLeastPrimary',\
                            'Government expenditure on education, total (% of GDP)' : 'governmentExpenditureOnEducation'})
data_edu = data_edu.reset_index()
data_edu = data_edu.fillna(0)
data_edu.head()
# Out:
# Series Name  countryName  childrenOutOfSchool  compulsoryEducation  \
# 0            Afghanistan              0.00000                  9.0
# 1                Albania              2.34458                  9.0
# 2                Algeria              0.72481                 10.0
# 3                Andorra              0.00000                 10.0
# 4                 Angola              0.00000                  6.0
#
# Series Name  educationalAttainmentAtLeastPrimary  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                       96.51884
# 4                                        0.00000
#
# Series Name  governmentExpenditureOnEducation
# 0                                     4.22836
# 1                                     3.96209
# 2                                     0.00000
# 3                                     3.25670
# 4                                     0.00000

# %% [markdown]
# * Economy

# %%
data_economy = pd.read_excel('panstwa.xlsx').drop_duplicates().dropna()
country_data2 = data_economy[['Country Code', 'countryName']]
del data_economy['2017 [YR2017]'], data_economy['2018 [YR2018]']
data_economy = data_economy.pivot(index='countryName', columns='Series Name', values='2016 [YR2016]')
data_economy = data_economy.rename(columns={'GDP per capita (current US$)': "GDPPerCapita", \
                                            'Population ages 0-14 (% of total population)': 'populationAges_0_14',\
                                            'Population ages 15-64 (% of total population)': 'populationAges_15_64',\
                                            'Population ages 65 and above (% of total population)':'populationAges_65_above',\
                                            'Population density (people per sq. km of land area)' : 'populationDensity',\
                                            'Rural population (% of total population)': 'ruralPopulation',\
                                            'Urban population (% of total population)':'urbanPopulation'})
data_economy = data_economy.reset_index()
data_economy = data_economy.fillna(0)
data_economy.head()
# Out:
# Series Name  countryName  GDPPerCapita  populationAges_0_14  \
# 0            Afghanistan    547.228110            44.272113
# 1                Albania   4124.108907            18.383696
# 2                Algeria   3946.421445            29.134452
# 3                Andorra  37224.108916             0.000000
# 4                 Angola   3506.072885            47.053352
#
# Series Name  populationAges_15_64  populationAges_65_above  populationDensity  \
# 0                       53.207964                 2.519923          54.197114
# 1                       68.660092                12.956211         104.967190
# 2                       64.857566                 6.007981          17.025957
# 3                        0.000000                 0.000000         164.461702
# 4                       50.685629                 2.261018          23.135064
#
# Series Name  ruralPopulation  urbanPopulation
# 0                     74.980           25.020
# 1                     41.579           58.421
# 2                     28.541           71.459
# 3                     11.752           88.248
# 4                     35.851           64.149

# %% [markdown]
# * Counties

# %%
country_data = country_data.drop_duplicates().dropna()
country_data = country_data.reset_index(drop=True)

country_data2 = country_data2.drop_duplicates().dropna()
country_data2 = country_data2.reset_index(drop=True)

country_data2['Continent'] = country_data['Continent']
country_data2 = country_data2.rename(columns={'Country Code': "countryCode", \
                                              'Country Name': 'countryName',\
                                              'Continent': 'continent'})
country_data2 = country_data2.fillna(0)
country_data2.head()
# Out:
#   countryCode  countryName continent
# 0         AFG  Afghanistan      Asia
# 1         ALB      Albania    Europe
# 2         DZA      Algeria    Africa
# 3         AND      Andorra    Europe
# 4         AGO       Angola    Africa

# %%
country_dict = pd.Series(country_data2['countryCode'].values, index=country_data2['countryName']).to_dict()

# %% [markdown]
# * Health

# %%
data_health = pd.read_excel('zdrowie.xlsx').drop_duplicates().dropna()
del data_health['2017 [YR2017]'], data_health['2018 [YR2018]']
data_health = data_health.pivot(index='countryName', columns='Series Name', values='2016 [YR2016]')
data_health = data_health.rename(columns={
                            'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)':'causeOfDeathByCommunicableDiseases', \
                            'Current health expenditure (% of GDP)': 'healthExpenditure',\
                            'Life expectancy at birth, total (years)': 'lifeExpectancy',\
                            'Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)':'mortalityRateDueToUnsafeWater',\
                            'Mortality rate, adult, female (per 1,000 female adults)' : 'mortalityFemaleRate',\
                            'Mortality rate, adult, male (per 1,000 male adults)': 'mortalityMaleRate',\
                            'Mortality rate, infant (per 1,000 live births)':'mortalityInfantRate',\
                            'People with basic handwashing facilities including soap and water (% of population)':'peopleWithBasicHandwashingFacilities'})
data_health = data_health.reset_index()
data_health = data_health.fillna(0)
data_health.head()
# Out:
# Series Name  countryName  lifeExpectancy  mortalityFemaleRate  \
# 0            Afghanistan          63.763              202.465
# 1                Albania          78.194               50.539
# 2                Algeria          76.298               83.113
# 3                Andorra           0.000                0.000
# 4                 Angola          59.925              203.100
#
# Series Name  mortalityMaleRate  mortalityInfantRate
# 0                      244.519                 51.2
# 1                       96.833                  8.2
# 2                      105.595                 21.0
# 3                        0.000                  3.0
# 4                      276.573                 55.5

# %% [markdown]
# ### Creating connections between tables

# %% [markdown]
# * Covid_mapped

# %%
for elem in range(len(data_covid['date'])):
    data_covid['date'][elem] = data_covid['date'][elem].date()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_covid
# Out:
#              country       date  totalCases  newCases  totalDeaths  newDeaths
# 0        Afghanistan 2020-01-01           0         0            0          0
# 1        Afghanistan 2020-01-02           0         0            0          0
# 2        Afghanistan 2020-01-03           0         0            0          0
# 3        Afghanistan 2020-01-04           0         0            0          0
# 4        Afghanistan 2020-01-05           0         0            0          0
# ...              ...        ...         ...       ...          ...        ...
# 21239  International 2020-02-28         705         0            4          0
# 21240  International 2020-02-29         705         0            6          2
# 21241  International 2020-03-01         705         0            6          0
# 21242  International 2020-03-02         705         0            6          0
# 21243  International 2020-03-10         696        -9            7          1
#
# [21244 rows x 6 columns]

# %%
data_covid['country'] = data_covid['country'].map(country_dict)
data_covid = data_covid.rename(columns={'country': 'countryCode'})
data_covid.set_index('countryCode', inplace = True)
data_covid.head()
# Out:
#                   date  totalCases  newCases  totalDeaths  newDeaths
# countryCode
# AFG         2020-01-01           0         0            0          0
# AFG         2020-01-02           0         0            0          0
# AFG         2020-01-03           0         0            0          0
# AFG         2020-01-04           0         0            0          0
# AFG         2020-01-05           0         0            0          0

# %% [markdown]
# * Education_mapped

# %%
data_edu['countryName'] = data_edu['countryName'].map(country_dict)
data_edu = data_edu.rename(columns={'countryName': 'countryCode'})
data_edu.set_index('countryCode', inplace = True)
data_edu.head()
# Out:
# Series Name  childrenOutOfSchool  compulsoryEducation  \
# countryCode
# AFG                      0.00000                  9.0
# ALB                      2.34458                  9.0
# DZA                      0.72481                 10.0
# AND                      0.00000                 10.0
# AGO                      0.00000                  6.0
#
# Series Name  educationalAttainmentAtLeastPrimary  \
# countryCode
# AFG                                      0.00000
# ALB                                      0.00000
# DZA                                      0.00000
# AND                                     96.51884
# AGO                                      0.00000
#
# Series Name  governmentExpenditureOnEducation
# countryCode
# AFG                                   4.22836
# ALB                                   3.96209
# DZA                                   0.00000
# AND                                   3.25670
# AGO                                   0.00000

# %% [markdown]
# * Economy_mapped

# %%
data_economy['countryName'] = data_economy['countryName'].map(country_dict)
data_economy = data_economy.rename(columns={'countryName': 'countryCode'})
data_economy.set_index('countryCode', inplace = True)
data_economy.head()
# Out:
# Series Name  GDPPerCapita  populationAges_0_14  populationAges_15_64  \
# countryCode
# AFG            547.228110            44.272113             53.207964
# ALB           4124.108907            18.383696             68.660092
# DZA           3946.421445            29.134452             64.857566
# AND          37224.108916             0.000000              0.000000
# AGO           3506.072885            47.053352             50.685629
#
# Series Name  populationAges_65_above  populationDensity  ruralPopulation  \
# countryCode
# AFG                         2.519923          54.197114           74.980
# ALB                        12.956211         104.967190           41.579
# DZA                         6.007981          17.025957           28.541
# AND                         0.000000         164.461702           11.752
# AGO                         2.261018          23.135064           35.851
#
# Series Name  urbanPopulation
# countryCode
# AFG                   25.020
# ALB                   58.421
# DZA                   71.459
# AND                   88.248
# AGO                   64.149

# %% [markdown]
# * Country_mapped

# %%
country_data2.set_index('countryCode', inplace = True)
country_data2.head()
# Out:
#              countryName continent
# countryCode
# AFG          Afghanistan      Asia
# ALB              Albania    Europe
# DZA              Algeria    Africa
# AND              Andorra    Europe
# AGO               Angola    Africa

# %% [markdown]
# * Health_mapped

# %%
data_health['countryName'] = data_health['countryName'].map(country_dict)
data_health = data_health.rename(columns={'countryName': 'countryCode'})
data_health.set_index('countryCode', inplace = True)
data_health.head()
# Out:
# Series Name  lifeExpectancy  mortalityFemaleRate  mortalityMaleRate  \
# countryCode
# AFG                  63.763              202.465            244.519
# ALB                  78.194               50.539             96.833
# DZA                  76.298               83.113            105.595
# AND                   0.000                0.000              0.000
# AGO                  59.925              203.100            276.573
#
# Series Name  mortalityInfantRate
# countryCode
# AFG                         51.2
# ALB                          8.2
# DZA                         21.0
# AND                          3.0
# AGO                         55.5

# %% [markdown]
# ### Creating databases

# %%
class Covid_ADBPLS(Base):
    __tablename__ = 'covid_ADBPLS'
    countryCode = Column(String(50), primary_key=True)
    date = Column(Date)
    totalCases = Column(Float, nullable = True)
    newCases = Column(Float, nullable = True)
    totalDeaths = Column(Float, nullable = True)
    newDeaths = Column(Float, nullable = True)

# %%
class Country_ADB(Base):
    __tablename__ = 'country_ADB'
    countryCode = Column(String(50), primary_key = True)
    countryName = Column(String(50), default = 'Unknown name')
    continent = Column(String(50), default = 'Unknown name')

# %%
class Edukacja_ADB(Base):
    __tablename__ = 'edukacja_ADB'
    countryCode = Column(String(50), primary_key = True)
    childrenOutOfSchool = Column(Float, nullable = True)
    compulsoryEducation = Column(Float, nullable = True)
    educationalAttainmentAtLeastPrimary = Column(Float, nullable = True)
    governmentExpenditureOnEducation = Column(Float, nullable = True)

# %%
class Economy_ADB(Base):
    __tablename__ = 'economy_ADB'
    countryCode = Column(String(50), primary_key=True)
    GDPPerCapita  = Column(Float, nullable = False)
    populationAges_0_14 = Column(Float, nullable = False)
    populationAges_15_64 = Column(Float, nullable = False)
    populationAges_65_above = Column(Float, nullable = False)
    populationDensity = Column(Float, nullable = False)
    ruralPopulation = Column(Float, nullable = False)
    urbanPopulation = Column(Float, nullable = False)

# %%
class Health_ADB(Base):
    __tablename__ = 'health_ADB'
    countryCode = Column(String(50), primary_key=True)
    causeOfDeathByCommunicableDiseases = Column(Float, nullable = False)
    healthExpenditure = Column(Float, nullable = False)
    lifeExpectancy = Column(Float, nullable = False)
    mortalityRateDueToUnsafeWater = Column(Float, nullable = False)
    mortalityFemaleRate = Column(Float, nullable = False)
    mortalityMaleRate = Column(Float, nullable = False)
    mortalityInfantRate = Column(Float, nullable = False)
    peopleWithBasicHandwashingFacilities = Column(Float, nullable = False)
    
Base.metadata.create_all(engine)

# %% [markdown]
# ### Inserting data into table

# %%
if engine.dialect.has_table(engine, "edukacja_ADB"):
    print("true")
# Out:
# true

# %%
data_covid.to_sql('covid_ADBPLS',engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# DatatypeMismatch                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#
# DatatypeMismatch: column "date" is of type integer but expression is of type timestamp without time zone
# LINE 1: ...ases", "totalDeaths", "newDeaths") VALUES ('AFG', '2020-01-0...
#                                                              ^
# HINT:  You will need to rewrite or cast the expression.
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-73-d83f9354a0e8> in <module>
# ----> 1 data_covid.to_sql('covid_ADB',engine, if_exists='append')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     982             )
#     983         else:
# --> 984             return meth(self, multiparams, params)
#     985
#     986     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1101             distilled_params,
#    1102             compiled_sql,
# -> 1103             distilled_params,
#    1104         )
#    1105         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1286         except BaseException as e:
#    1287             self._handle_dbapi_exception(
# -> 1288                 e, statement, parameters, cursor, context
#    1289             )
#    1290
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1480             elif should_wrap:
#    1481                 util.raise_(
# -> 1482                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1483                 )
#    1484             else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1226                 if not evt_handled:
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#    1230             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     855     def do_executemany(self, cursor, statement, parameters, context=None):
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#     859
#
# ProgrammingError: (psycopg2.errors.DatatypeMismatch) column "date" is of type integer but expression is of type timestamp without time zone
# LINE 1: ...ases", "totalDeaths", "newDeaths") VALUES ('AFG', '2020-01-0...
#                                                              ^
# HINT:  You will need to rewrite or cast the expression.
#
# [SQL: INSERT INTO "covid_ADB" ("countryCode", date, "totalCases", "newCases", "totalDeaths", "newDeaths") VALUES (%(countryCode)s, %(date)s, %(totalCases)s, %(newCases)s, %(totalDeaths)s, %(newDeaths)s)]
# [parameters: ({'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 1, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 2, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 3, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 4, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 5, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 6, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 7, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}, {'countryCode': 'AFG', 'date': datetime.datetime(2020, 1, 8, 0, 0), 'totalCases': 0, 'newCases': 0, 'totalDeaths': 0, 'newDeaths': 0}  ... displaying 10 of 21244 total bound parameter sets ...  {'countryCode': None, 'date': datetime.datetime(2020, 3, 2, 0, 0), 'totalCases': 705, 'newCases': 0, 'totalDeaths': 6, 'newDeaths': 0}, {'countryCode': None, 'date': datetime.datetime(2020, 3, 10, 0, 0), 'totalCases': 696, 'newCases': -9, 'totalDeaths': 7, 'newDeaths': 1})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
country_data2.to_sql("country_ADB",engine, if_exists='append')

# %%
data_edu.to_sql("edukacja_ADB",engine, if_exists='append')

# %%
data_economy.to_sql("economy_ADB",engine, if_exists='append')

# %%
data_health.to_sql("health_ADB",engine, if_exists='append')

# %% [markdown]
# ### Chcecking correctness

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind = engine)
session = Session()
stmt = "select count (*) from \"edukacja_Karo2\""
print(session.execute(stmt).fetchall())
# Out:
# [(182,)]

# %%
session_stmt1 = session.query(func.count(Edukacja_Karo.compulsoryEducation))
print(session_stmt1)
session_results1 = session_stmt1.all()
print(session_results1)
# Out:
# SELECT count("edukacja_Karo2"."compulsoryEducation") AS count_1
# FROM "edukacja_Karo2"
# [(182,)]
